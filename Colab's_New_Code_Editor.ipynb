# %%
import cv2
img = cv2.imread('roof_image.jpg')

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F190ACF6080>

# %%
import numpy as np

imgray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
ret,thresh = cv2.threshold(imgray,127,255,0)
image, contours, hierarchy = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)

# %%
index=-1
for i in contours:
  index+=1
  out_img = cv2.drawContours(img, contours, index, (randrange(255),randrange(255),randrange(255)), 3)

# %%
cv2_imshow(out_img)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F190ACFAB70>
